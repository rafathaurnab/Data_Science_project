# %% [markdown]
# # Activity 1: Data inventory and environment setup

# %% [markdown]
# ![](https://img.shields.io/badge/Instruction-blue) ![](https://img.shields.io/badge/Step_1-blue)
#
# ## 1.1 Catalogue known and candidate datasets
#
# Record each dataset relevant to AusVille, such as:
#
# - public transport feeds
# - traffic counts
# - population
# - landuse data
#
# For each, complete the following columns in full sentences:
#
# - data source and provider
# - format and access method
# - temporal coverage and refresh frequency
# - spatial coverage and granularity
# - licensing or privacy constraints
# - initial quality concerns you anticipate (e.g., missing values at peak hours, irregular timestamps).
#
# If you are unsure about a field, write an explicit assumption rather than leaving it blank.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# Publicv transport Feed
#
# The data Source and provider is PTV (for australia) Which they provide it in their portals. The data is formated in General Transit Feed Specification for live updates. accessed via the online portal. The data is changed with temporal cove

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_2-blue)
#
# ## 1.2 Use Copilot to reveal gaps and risks
#
# Paste a sanitised summary of your inventory into Copilot and ask:
#
# >“Given this draft data inventory for a smartcity mobility dashboard, what critical gaps, integration challenges, or bias risks are likely? Propose practical mitigations we could implement in a student project (e.g., proxy data, sampling strategies, validation methods).”
#
# Discuss the response. Make sure that you:
#
# - keep the ideas that make sense for our context
# - remove anything infeasible
# - rewrite vague items into concrete next steps (e.g., “Validate pedestrian counters by crosschecking with specialevent calendars for anomalies”)
#
# Update your inventory notes accordingly.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_3-blue)
#
# ## 1.3 Set up project workspace
#
# Create a clean folder structure that separates data, notebooks, outputs, and docs.
#
# In this Jupyter Notebook, add a short project header that explains the purpose of the notebook, the inputs it expects, and the outputs it produces.
#
# Add 2 cells:
#  - one cell to print your environment information (Python version and key library versions)
#  - another one to establish relative paths so your work remains portable
#
# Finish by drafting a `README.md` in the project root explaining the folder layout and how to run the notebook.
#
# If you aren’t sure how to explain a structure clearly, ask Copilot:
#
# >“Suggest a concise README section that explains this folder structure to a future teammate and includes two reproducibility practices we can commit to.”
#
# Adapt the output to reflect what you actually created; do not include claims you did not implement.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_4-blue)
#
# ## 1.4 Validate data understanding before analysis
#
# Each teammate writes a brief note (3-4 sentences) on one risk they will monitor in early analysis and how they will detect it.
#
# Risk examples:
#
# - seasonality misinterpreted as growth
# - duplicated trips
# - geocoding drift)
#
# Combine these into a single paragraph at the bottom of your inventory and label it "Early Validation Plan", or write your paragraph below.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>
