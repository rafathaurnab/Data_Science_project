# %% [markdown]
# # Activity 1: Building statistical KPIs

# %% [markdown]
# ![](https://img.shields.io/badge/Instruction-blue) ![](https://img.shields.io/badge/Step_1-blue)
#
# ## 1.1 Establish your analytical focus
#
# Begin by revisiting the City Council’s prompt:
#
# >“What does typical transport usage look like in AusVille?”
#
# In your project team, discuss what types of basic statistics would help answer this.
#
# Think beyond "average values" and consider:
#
# - variability
# - distribution
# - differences across modes
# - time periods
#
# Before touching Python, ask an LLM to help you think more critically about your direction by prompting it with a question such as:
#
# >"Given a transport mobility dataset, what descriptive statistics and aggregation levels would be most useful for understanding typical usage? Suggest metrics and explain why they are meaningful."
#
# Use its suggestions to refine your plan.
#
# ⚠️ Important: The goal here is to frame your statistical approach rather than immediately executing code.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_2-blue)
#
# ## 1.2 Calculate core KPIs
#
# No you can begin computing the overall descriptive statistics for the entire AusVille dataset.
#
# Start with the fundamentals (<span style="color:#B49AD2">mean, median, and mode</span>) to establish typical usage patterns, and then extend into measures of dispersion (<span style="color:#B49AD2">range, variance, standard deviation, and IQR</span>) to understand how variable behaviour is across the system.
#
# Using this reasoning, calculate the following overall KPIs:
#
# - average daily trips
# - mean trip duration
# - total passenger volume
#
# As you perform each calculation, pause to validate your results with an LLM.
#
# For example, you might prompt:
#
# >"Here are the values we calculated for average daily trips and mean trip duration. What validation checks should we run to ensure these numbers make sense?"
#
# This helps you identify potential issues, such as:
#
# - outliers
# - unit mismatches
# - aggregation errors before moving on

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
import pandas as pd
from google.colab import files
import io

# Since the Drive link is restricted, let's upload the file directly
print("Please upload 'ausville_transport_data.csv' below:")
uploaded = files.upload()

for fn in uploaded.keys():
  df = pd.read_csv(io.StringIO(uploaded[fn].decode('utf-8')))
  print(f"Successfully loaded {fn}")
  display(df.head())
# Out:
# Please upload 'ausville_transport_data.csv' below:
#      <input type="file" id="files-1b4c746c-5e3b-4709-98ba-1511b429269e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b4c746c-5e3b-4709-98ba-1511b429269e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
from google.colab import drive
# Using the standard '/content/drive' path which Colab expects
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os

# Correcting the path to include the mandatory /content/drive/ prefix
# Also fixed the common typo from 'Ntebooks' to 'Notebooks'
file_path = '/content/drive/MyDrive/Colab Notebooks/df_csv.csv'

try:
    df = pd.read_csv(file_path)
    display(df.head())
except FileNotFoundError:
    print(f"Error: Still cannot find the file at {file_path}.")
    print("Please verify the folder names (like 'Colab Notebooks') and the filename 'df_csv.csv' in your Drive.")
# Out:
# /tmp/ipykernel_215/2964090360.py:9: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#   Business_Date Day_of_Week        Day_Type   Mode Train_Number Line_Name  \
# 0    2023-07-10      Monday  Normal Weekday  Metro         6001   Sunbury
# 1    2023-07-10      Monday  Normal Weekday  Metro         6003   Sunbury
# 2    2023-07-10      Monday  Normal Weekday  Metro         6005   Sunbury
# 3    2023-07-10      Monday  Normal Weekday  Metro         6007   Sunbury
# 4    2023-07-10      Monday  Normal Weekday  Metro         6009   Sunbury
#
#       Group Direction   Origin_Station Destination_Station  ...  \
# 0  Northern         D  Flinders Street             Sunbury  ...
# 1  Northern         D  Flinders Street             Sunbury  ...
# 2  Northern         D  Flinders Street             Sunbury  ...
# 3  Northern         D  Flinders Street             Sunbury  ...
# ...

# %%
# Corrected the column name from 'Passenger Boardings' to 'Passenger_Boardings'
data = df["Passenger_Boardings"].dropna()
data.isna().sum()
# Out:
# np.int64(0)

# %%
mean_val = data.mean()
median_val = data.median()
mode_val = data.mode()
range_val = data.max() - data.min()
variance_val = data.var()
std_val = data.std()

print(mean_val)
print(median_val)
print(mode_val)
print(range_val)
print(variance_val)
# Out:
# 14.805655181354252
# 0.0
# 0    0
# Name: Passenger_Boardings, dtype: int64
# 1900
# 1164.92195876335

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_3-blue)
#
# ## 1.3 Create segmented summary tables
#
# Once you have the overall KPIs, you will use `groupby()` to generate segmented summaries that reveal how mobility patterns differ across the city.
#
# Your task is to create grouped summaries for:
#
# - transport mode
# - day of week
# - hour of day
# - route
#
# For each segment, calculate appropriate <span style="color:#B49AD2">descriptive statistics</span> such as mean, median, count, or standard deviation.
#
# Rather than mechanically grouping every field, think about what would best support city planning decisions. For instance:
#
# - Which routes show the highest variability in ridership?
# - At what hours do particular modes become congested?
# - Do certain days show unusually high demand?
#
# To support this decision‑making, use an LLM as a collaborative reasoning partner.
#
# Prompt something like:
#
# >"We are segmenting AusVille mobility data by mode, day of week, hour, and route. Which additional segmented statistics should we calculate to reveal meaningful patterns, and how can we test whether our grouping logic is sound?"
#
# This encourages you to improve your statistical design, not just run predefined code.
#
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Convert time to analytics
df['Arrival_Time_Scheduled'] = pd.to_datetime(df['Arrival_Time_Scheduled'], errors='coerce')
df['Departure_Time_Scheduled'] = pd.to_datetime(df['Departure_Time_Scheduled'], errors='coerce')
df['Hour'] = df['Arrival_Time_Scheduled'].dt.hour
df['Business_Date'] = pd.to_datetime(df['Business_Date'])

# Compute ridership (boarding + alightings)
# Corrected 'Passenger_Alighting' to 'Passenger_Alightings' to match dataset
df['Rideship'] = df['Passenger_Boardings'] + df['Passenger_Alightings']
# Out:
# /tmp/ipykernel_215/4169214084.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Arrival_Time_Scheduled'] = pd.to_datetime(df['Arrival_Time_Scheduled'], errors='coerce')
# /tmp/ipykernel_215/4169214084.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Departure_Time_Scheduled'] = pd.to_datetime(df['Departure_Time_Scheduled'], errors='coerce')

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_4-blue)
#
# ## 1.4 Export your outputs
#
# When your summaries are complete, export them to CSV files that will later serve as inputs for your dashboard prototype.
#
# Save your files using the following names:
#
# - `kpi_summary.csv` containing your overall descriptive statistics and KPIs
# - `hourly_patterns.csv` containing your hour‑by‑hour segmented summary
#
# Before finalising the export, use an LLM to validate your structure:
#
# >"These are the columns included in our KPI and hourly pattern exports. Do these formats align with how a dashboard designer would expect to use them? Suggest improvements if needed."
#
# Revise your files if the LLM identifies missing fields, unclear labels, or opportunities to make the data more dashboard‑friendly.
#
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here
df.to_csv('kpi_summary.csv', index=False)

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
# ---
#
# # Activity 2: What influences ridership?

# %% [markdown]
# ![](https://img.shields.io/badge/Instruction-blue) ![](https://img.shields.io/badge/Step_1-blue)
#
# ## 2.1 Understanding correlation v.s. causation
#
# Start by reviewing the purpose and limitations of correlation analysis with your team.
#
# Discuss in your own words what <span style="color:#B49AD2">correlation</span> represents, why it does not imply <span style="color:#B49AD2">causation</span>, and how a correlation matrix can reveal broad patterns across many variables.
#
# Before using Python, ask an LLM to expand your conceptual understanding by prompting:
#
# >"Explain correlation vs. causation using a transport dataset. Provide examples of meaningful correlations and examples of misleading or spurious correlations that analysts should be careful about."
#
# Use the LLM’s explanation to deepen your team’s framing of the task.
#
# This conceptual clarity will help prevent over‑interpreting statistical results later.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_2-blue)
#
# ## 2.2 Compute a correlation matrix
#
# Move into your Python environment and compute a correlation matrix that includes ridership measures (<span style="color:#B49AD2">e.g., daily trips, passenger volume, trip duration</span>) together with key demographic factors available in your dataset (<span style="color:#B49AD2">e.g., median age, population density, household income, car ownership rate</span>).
#
# The goal is not to mechanically run `.corr()`, but to think critically about:
#
# - Which variables are appropriate to compare
# - Whether they are numerical, scaled sensibly, or need preprocessing
# - Whether the matrix reveals meaningful strengths and signs of relationships
#
# Once you generate the matrix, export it or display it clearly for group discussion.
#
# To support reasoning, prompt an LLM with:
#
# >"Here is our correlation matrix between ridership variables and demographic features. Identify which correlations are strongest, weakest, or potentially misleading. Suggest questions we should ask to interpret these results responsibly."
#
# Use the LLM’s feedback to refine which relationships to examine more deeply.
#
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_3-blue)
#
# ## 2.3 Identify and interpret key relationships
#
# Choose 2-3 of the strongest correlations (positive or negative) and attempt to interpret what they might suggest.
#
# Focus on whether the relationships make sense within the context of AusVille and whether they could help planners improve mobility outcomes.
#
# For each correlation, consider:
#
# - Is this relationship plausible given what we know about real transport behaviour?
# - Could the correlation be driven by an external variable not in the dataset?
# - Does the correlation remain stable across demographic segments or time periods?
#
# Use an LLM as a critical collaborator by prompting:
#
# >"Given these correlations, provide possible domain-based explanations, and identify at least three alternative reasons (confounders or data issues) that might produce the same pattern."
#
# ⚠️ Important: This step emphasises interpretation, not calculation.
#
# Your insights should be grounded in reasoning rather than numerical strength alone.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_4-blue)
#
# ## 2.4 Validation: Guarding against spurious correlations
#
# Finally, evaluate the trustworthiness of your conclusions.
#
# <span style="color:#B49AD2">Correlation analysis</span> often reveals relationships that look strong but have no actual causal basis.
#
# Use the following validation checks:
#
# - <span style="color:#B49AD2">Data quality</span>: Are any variables heavily skewed, sparse, or containing outliers?
# - <span style="color:#B49AD2">Mathematical artefacts</span>: Are two variables correlated simply because they share a denominator or scale?
# - <span style="color:#B49AD2">Domain sense-check</span>: Would transport planners find the relationship reasonable?
#
# Use an LLM to support validation by prompting:
#
# >"Evaluate whether these relationships could be spurious. Suggest statistical checks, visualisations, or dataset assumptions we should examine to confirm or challenge the validity of these correlations."
#
# Based on this critique, revise or downgrade correlations that cannot be justified.
#
# The goal is to end the activity with a small set of plausible, decision-relevant correlations that you may later choose to visualise in your dashboard prototype.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
# ---
#
# # Activity 3: Testing differences in transport delays

# %% [markdown]
# ![](https://img.shields.io/badge/Instruction-blue) ![](https://img.shields.io/badge/Step_1-blue)
#
# ## 3.1 Frame the inferential question
#
# As a team (3-4 students), clarify what you are trying to infer about the population of trips from your sample in the dataset.
#
# Agree on operational definitions for delay (e.g., `actual_departure` - `scheduled_departure` or `equivalent`) and confirm your comparison groups (bus vs train).
#
# Use an LLM (copy/past prompt) to refine your framing and check assumptions before you code:
#
# >"We are testing whether average delay differs between bus and train services in a cleaned urban mobility dataset. Help us specify the population vs sample, define our null and alternative hypotheses clearly, and list assumptions for a two‑sample t‑test (independence, approximate normality, similar or unequal variances). Suggest quick diagnostics to check these assumptions with Python."
#
# In your notes, record:
#
# - population of interest
# - sampling logic or data slice
# - H0H_0H0: μbus=μtrain\mu_{\text{bus}} = \mu_{\text{train}}μbus=μtrain
# - HAH_AHA (two‑sided difference)
# - assumptions to be checked

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_2-blue)
#
# ## 3.2 Decompose the analysis and run assumption checks
#
# Before running a t‑test, decompose the task:
#
# - Data slices:
#     - Create two comparable series (bus delays, train delays) with the same units.
#     - Filter out impossible values (e.g., negative beyond data definition) and document any exclusions.
# - Distribution checks: quickly inspect shape (histogram or kernel density), centre (mean/median), and spread (std/IQR).
# - Normality & sample size:
#     - For large nnn, the Central Limit Theorem supports t‑tests for mean differences.
#     - Otherwise, consider robustness via medians or non‑parametrics.
# - Variance structure: Decide equal‑variance vs Welch’s t‑test (unequal variances).
#
# Use an LLM (copy/past prompt) to accelerate diagnostics design:
#
# >"Given two delay arrays (bus, train), propose concise Python snippets to: (1) visualise distributions, (2) check outliers/long tails, (3) compare group variances, and (4) justify using Welch’s t‑test if variances differ. What thresholds or visual cues would you use to flag problems?"
#
# Implement the minimal checks the LLM suggests (plots, summary stats).
#
# If assumptions look severely violated (extreme skew, tiny n), ask the LLM for alternative tests (e.g., Mann-Whitney U) and document why.
#
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_3-blue)
#
# ## 3.3 Conduct the hypothesis test and compute confidence intervals
#
# Run a two‑sample t‑test (Welch’s by default unless you justify equal variances).
#
# Record the following:
#
# - test statistic
# - degrees of freedom
# - p‑value
#
# Next, compute 95% confidence intervals for the mean delay of each mode and, if possible, a CI for the mean difference.
#
# Ask an LLM (copy/past prompt) to help verify calculations and cross‑check your interpretation:
#
# >"These are our summary stats for delays by mode and the Welch t‑test output (t, df, p). Compute/verify 95% confidence intervals for each group mean and for the mean difference. Explain how to interpret the CI bounds in plain language and how they relate to the p‑value."
#
# Use the response to adjust any errors and to confirm whether your result supports rejecting H0H_0H0 at your chosen α\alphaα (e.g., 0.05).
#
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_4-blue)
#
# ## 3.4 Interpret for non‑technical planners and iterate
#
# Your result only becomes useful when a planner can act on it.
#
# Draft a 3-5 sentence, non‑technical interpretation that states:
# - what you tested
# - what you found (direction and practical size of the difference)
# - uncertainty (confidence intervals)
# - a planning implication (e.g., “prioritise reliability interventions for buses during peak hours if delays are materially higher”).
#
# Use an LLM (copy/past prompt) as a communication coach:
#
# >"Rewrite our statistical findings for non‑technical city planners in 3–5 sentences. Avoid jargon. Emphasise what’s different, how confident we are, and one practical action this suggests for service planning."
#
# Then, stress‑test your message for overclaiming with a follow‑up LLM prompt:
#
# >"Critique the statement for potential over‑interpretation or causal language. Suggest one sentence that communicates limitations (data scope, assumptions, or confounders)."

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
# ---
#
# # Activity 4: Route performance metrics analysis

# %% [markdown]
# ![](https://img.shields.io/badge/Instruction-blue) ![](https://img.shields.io/badge/Step_1-blue)
#
# ## 4.1 Frame the problem and confirm business rules
#
# Begin by agreeing, as a team, on what "delay" means in your dataset (e.g., `actual_departure` - `scheduled_departure`, or `actual_arrival` - `scheduled_arrival`) and the unit you will use (minutes recommended).
#
# Next, set an on‑time threshold appropriate for AusVille (e.g., “a trip is on‑time if delay ≤ 5 minutes.”).
#
# ⚠️ Important: Do not guess; ask an LLM (copy/past prompt) to help you justify and refine this threshold using transport practice and your data’s characteristics:
#
# >"We’re building route performance metrics for a smart city. Our data has trip‑level scheduled and actual times. Propose an on‑time threshold (in minutes) that balances passenger expectations and operational realism. Suggest pros/cons of 0, 3, 5, and 10 minutes, and recommend a default plus a sensitivity check. Also flag pitfalls (early departures, negative delays, missing times)."
#
# From the LLM’s guidance, choose a default threshold (e.g., 5 minutes) and note at least one alternative to test later.
#
# Document your definitions and choices, so your decisions are transparent.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_2-blue)
#
# ## 4.2 Decompose the analysis and prepare clean inputs
#
# Create a clear plan before coding.
#
# Decide the granularity of the output (one row per route).
#
# List the columns you will need:
#
# - route identifier (and name, if available)
# - trip‑level delay
# - a boolean for on‑time
# - any filters (e.g., exclude cancelled trips if that is encoded separately).
#
# In the Python notebook, compute trip‑level delay with a single consistent definition, and then clean any impossible or ambiguous values, such as:
#
# - extremely large delays that indicate data entry errors
# - negative delays if you do not treat “early” as negative delay)
#
# Use an LLM (copy/past prompt) to spot gaps in your plan and propose quick diagnostics:
#
# >"Given trip‑level scheduled vs actual times, provide concise Python steps to: (1) compute delay in minutes, (2) create an on‑time flag using our chosen threshold, (3) exclude malformed records safely, and (4) summarise data quality (count, nulls, five‑number summaries, extreme values). Suggest one simple sensitivity check."
#
# Run the suggested diagnostics.
#
# If you discover unexpected values (e.g., many negative or null delays), decide and note how you will treat them (clip to 0, drop, or separate as "early").
#
# This decomposition prevents hidden errors later.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_3-blue)
#
# ## 4.3 Compute route‑level metrics and rank routes
#
# Aggregate to route‑level using `groupby()` (or equivalent).
#
# For each route, compute:
#
# - Average delay (consider both mean and median to handle skew; choose one as your headline metric but keep the other for validation).
# - On‑time percentage (the share of trips meeting your on‑time threshold).
# - Optional supporting fields that help planners: total trips, standard deviation or IQR of delay (variability matters).
#
# With these columns in hand, produce two rankings:
#
# - best performing (highest on‑time %, lowest delay)
# - worst performing (lowest on‑time %, highest delay).
#
# Now, use an LLM (copy/past prompt) to critique and improve your design:
#
# >"Here is our drafted route performance table (columns and sample rows). Critique our metric choices. Are there routes with too few trips to be reliable? Should we use median instead of mean for skewed routes? Propose 2–3 validation checks and a clear decision rule for ties in rankings."
#
# Apply the LLM’s feedback to iterate. For example:
#
# - Set a minimum trip count (e.g., exclude or flag routes with fewer than 30 trips)
# - Switch your headline average from mean to median if skew is substantial
#
# Re‑rank after changes and keep a short note of what you changed and why.
#
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_4-blue)
#
# ## 4.4 Validate, run a quick sensitivity check, and export
#
# Validation should be fast but purposeful.
#
# First, compute simple summary statistics across all routes:
# - overall average of route means
# - distribution of on-time percentages
# - check that sum of trips by route equals total trips retained
#
# Second, perform a sensitivity check on your on-time threshold:
#
# - recompute on‑time % using 3 minutes as a stricter threshold
# - observe whether the top/bottom five routes change materially
#
# Use an LLM (copy/past prompt) to help you interpret the stability of your rankings:
#
# >"We computed route on‑time % using 5 minutes and again using 3 minutes. Here are top/bottom routes under each threshold. Help us assess stability: which routes are robust, which are borderline, and what should we report to planners about sensitivity?"
#
# Finally, export a tidy, dashboard‑ready CSV named route_performance.csv that includes, at minimum:
#
# - route_id
# - route_name (if available)
# - trip_count
# - avg_delay_minutes (and/or median_delay_minutes)
# - on_time_pct_threshold_5m (or your chosen default)
# - any flags you used (e.g., low_sample_flag)
#
# ⚠️ Important: Ensure consistent data types, clear column names, and no mixed units.
#
# Upload `route_performance.csv` to your team’s VU Collaborate submission area along with a brief note (4-6 lines) capturing:
#
# - your definitions
# - threshold(s)
# - validation steps
# - one sentence on how the metric informs Power BI design (e.g., a route league table plus conditional formatting for thresholds)
#
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
# ---
#
# # Activity 5: Prototype dashboard visualisations

# %% [markdown]
# ![](https://img.shields.io/badge/Instruction-blue) ![](https://img.shields.io/badge/Step_1-blue)
#
# ## 5.1 Import Python visualisation libraries
#
# Before creating prototype visualisations to guide your <span style="color:#B49AD2">Urban Mobility Dashboard</span> design in Power BI, you must install two Python libraries:
#
# - Matplotlib
# - Seaborn
#
# Run the following commands to install the libraries:

# %%
pip install matplotlib
pip install seaborn

# %% [markdown]
# ![](https://img.shields.io/badge/Step_2-blue)
#
# ## 5.2 Frame the problem and use an LLM for guidance
#
# Before writing any code, identify what insights each visual should reveal.
#
# Ask an LLM something like:
#
# >"I am prototyping 4 visualisations for a Smart City transport dashboard: a daily trips time series, hourly heatmap, mode comparison bar chart, and correlation heatmap. For each one, what question should it answer for city planners, and what design elements should I focus on?"
#
# Use the response to define your design intentions.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_3-blue)
#
# ## 5.3 Prototype visualisation 1: Time series of daily trips
#
# Your goal is to understand long‑term movement patterns (growth, dips, weekend variation).
#
# Write Python code to produce a daily line plot.
#
# Ask an LLM to suggest:
#
# - better axis labels
# - colour choices for accessibility
# - smoothing options (e.g., rolling average)
#
# Iterate once based on LLM suggestions. Focus on:
#
# - signal versus noise
# - stakeholder usefulness
# - readability
#
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_4-blue)
#
# ## 5.4 Prototype visualisation 2: Hourly heatmap
#
# Your goal is to show when transport usage peaks across the day and week.
#
# 1. Create a pivot table:
#
#      - rows = weekday
#     - columns = hour
#
# 2. Use Seaborn to produce a heatmap.
#
# Ask an LLM:
# - "Is this heatmap readable for non‑technical council staff?"
# - "How can I improve the colour scale or annotations?"
#
# Incorporate one improvement.
#
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_5-blue)
#
# ## 5.5 Prototype visualisation 3: Mode comparison bar chart
#
# Your goal is to compare the popularity of transport modes (bus, train, tram, etc.).
#
# 1. Group the dataset by mode and calculate total passenger counts.
#
# 2. Plot a Seaborn bar chart.
#
# Ask an LLM:
#
# - "whether a bar, stacked bar, or proportional bar chart is more suitable?"
# - "how to adjust labels or ordering for clarity?"
#
# Update your prototype with the improved design.
#
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_6-blue)
#
# ## 5.6 Prototype visualisation 4: Correlation heatmap
#
# Your goal is to explore how numerical variables (passenger count, delays, trip distance, etc.) relate to each other.
#
# 1. Select only numerical columns.
#
# 2. Compute correlations.
#
# 3. Produce a Seaborn heatmap.
#
# Ask an LLM:
#
# - "Which correlations here might be useful to highlight in the Power BI dashboard, and why?"
# - "How can I visually emphasise the most important relationships?"
#
# Refine accordingly.
#
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_7-blue)
#
# ## 5.7 Synthesis: Choose your final dashboard visuals
#
# Using your four prototypes, decide which visual designs you would likely carry forward into Power BI.
#
# Ask an LLM:
#
# >"Based on these prototypes, which chart designs are most suitable for a Smart City transport dashboard, and what improvements should I make when recreating them in Power BI?"
#
# Write a short justification (5-6 sentences):

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>
