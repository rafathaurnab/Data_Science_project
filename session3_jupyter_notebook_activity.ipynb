# %% [markdown]
# # Activity 1: Framing data pre-clean

# %% [markdown]
# ![](https://img.shields.io/badge/Instruction-blue) ![](https://img.shields.io/badge/Step_1-blue)
#
# ## 1.1 Impacts of the wrong cleaning order
#
# Who could be misled if the wrong cleaning order is chosen?
#
# - planners
# - operations teams
# - commuters
# - etc
#
# Write a short list (e.g., planners, operations teams, commuters).

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_2-blue)
#
# ## 1.2 LLM‑supported cleaning plan
#
# Now open Copilot and paste your list of issues.
#
# Use this prompt:
#
# >“Given these AusVille data quality issues [paste list], what order should we clean the data in, and why? Consider risk, dependencies between issues, and potential impacts on decision‑making.”
#
# Read the response together and discuss:
#
# - What do you agree with?
# - What do you disagree with?
# - Which cleaning steps clearly depend on other problems being fixed first?
# - What risks did Copilot identify that you hadn’t considered?
#
# If needed, ask a follow‑up:
#
# >"Explain one risk of fixing dates before removing duplicates, or removing duplicates before fixing dates."
#
# Your goal is to produce a defensible cleaning order, not a perfect one.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_3-blue)
#
# ## 1.3 One‑sentence team decision
#
# As a team, write one sentence:
#
# >“Our most critical cleaning step is ____, because if we do not fix it first, ____.”
#
# You will use it immediately in the main activity.
# This sentence captures the reasoning behind your cleaning plan.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
# ---
#
# # Activity 2: Cleaning data with purpose

# %% [markdown]
# ![](https://img.shields.io/badge/Instruction-blue) ![](https://img.shields.io/badge/Step_1-blue)
#
# ## 2.1 Inspect the dataset
#
# Explore all the columns in the dataset:
#
# - identify how many values are missing
# - check whether specific routes, dates, or service types have more missing info
# - note any suspicious patterns
#
# Then, as a team, discuss possible reasons the data might be missing, such as:
#
# - broken sensors
# - incomplete operator reporting
# - peak‑hour upload delays
# - route‑specific data quality issues
#
# Now paste your notes into Copilot:
#
# >"We are first‑year data science students analysing a smart‑city transport dataset. Based on this summary, identify two plausible reasons for missing passenger counts and what evidence we could check next workshop to confirm or disprove them."
#
# Use the output critically. Keep only insights that make sense in context.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_2-blue)
#
# ## 2.2 Choose and apply median imputation by route type
#
# You will now implement median imputation grouped by route type.
#
# ⚠️ Important: The coding is not the main goal; the reasoning is.
#
# As a team, answer:
#
# - Why use median instead of mean or mode?
# - Why group by route type?
# - What assumptions are you making about this data?
# - What risks does this introduce?
#
# Use Copilot to support your thinking:
#
# >"Here is our imputation plan: [paste your description]. Identify two risks of using median‑by‑route‑type imputation and suggest one additional check to ensure we are not introducing bias."
#
# Refine your plan based on the useful parts of Copilot’s feedback, and then implement the imputation.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %%
---

![](https://img.shields.io/badge/Step_3-blue)

## 2.3 Validate your imputation

Cleaning is never complete without validation.
Compare dataset before and after imputation:

- plot distributions
- compare summary statistics
- look for shifts in medians or unusual spikes

Interpret the results in plain language:

- Did the distribution stay believable?
- Did certain route types change unexpectedly?
- Would a city planner be misled by your cleaned data?

Use Copilot again:

>"Based on these before/after differences [paste text summary], what patterns suggest our imputation may distort decision‑making? Provide two interpretations suitable for a city planner."

Use only the interpretations that match your evidence.
Add your conclusions.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_4-blue)
#
# ## 2.4 Write a clear, defensible justification
#
# In 4-5 sentences, explain:
#
# - what you did
# - why you chose this method
# - which alternatives you rejected and why
# - how your validation supports your decision
#
# If needed, refine with Copilot:
#
# >"Rewrite this justification to be clear and suitable for a non‑technical city planning audience."
#
# Imputation Strategy Justification:

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
# ---
#
# # Activity 3: Data cleaning foundations with Copilot

# %% [markdown]
# ![](https://img.shields.io/badge/Instruction-blue) ![](https://img.shields.io/badge/Step_1-blue)
#
# ## 3.1 Frame the cleaning problem
#
# Strong problem framing leads to higher‑quality AI output.
#
# Analysts who can clearly specify the requirements of a cleaning process avoid downstream analysis errors.
#
# Example starting sentence (⚠️ do not copy verbatim):
#
# > "I am preparing journey‑level mobility data for AusVille’s Move AusVille dashboard. I need to remove duplicates using a composite key and standardise date‑time and categoricals…"
#
#
# In your own words, write a short prompt to Copilot that explains:
#
# - what dataset you’re working with
# - which data-quality issues have been identified
# - what today’s cleaning goals are
# - why each issue matters for reliability of a Smart City dashboard

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_2-blue)
#
# ## 3.2 Decompose the cleaning tasks
#
# In industry, data-cleaning pipelines fail when analysts jump into coding without a plan.
#
# Decomposition ensures your logic is transparent, testable, and maintainable.
#
# Ask Copilot to help you break the cleaning job into logical sub‑tasks, such as:
#
# - Identify and remove duplicates using `trip_id` + `timestamp`.
# - Detect and convert inconsistent `departure_time` and `arrival_time` into a single standard datetime format.
# - Identify inconsistencies in `transport_mode` (capitalisation, spacing, and misspellings).
# - Propose validation checks for each step.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_3-blue)
#
# ## 3.3 Generate initial code snippets with Copilot
#
# Analysts rarely accept AI-generated code "as-is". You gain professional skill by iteratively improving the logic, clarity, and reliability.
#
# Using your decomposed tasks, prompt Copilot to generate Python code (Pandas) that:
#
# - drops duplicate rows using `trip_id` + `timestamp`
# - converts time strings into datetime objects, handling multiple formats
# - cleans and standardises `transport_mode`
#
# When Copilot returns code, ask it to:
#
# - add inline comments explaining the logic
# - rewrite unclear variables
# - add validation prints (e.g., number of duplicates before/after)
# - propose alternative approaches if needed

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_4-blue)
#
# ## 3.4 Test and validate the cleaning steps
#
# Testing is the difference between <span style="color:#B49AD2">“code that runs”</span> and <span style="color:#B49AD2">“code you trust”</span>.
#
# In real analytics environments, failure to validate leads directly to flawed policy decisions.
#
# Ask Copilot to help you write quick validation checks, such as:
#
# - confirming no duplicate records remain
# - verifying that datetime fields contain only valid formats
# - listing unique values in `transport_mode` after cleaning
# - checking for impossible trip durations (negative or > 24 hours)
#
# Review errors or unexpected behaviours, and request refinements from Copilot.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_5-blue)
#
# ## 3.5 Iterative improvement
#
# Based on your validation results, give Copilot instructions to refine the pipeline.
#
# Examples:
# >- "Rewrite the duplicate-removal step to ensure the earliest timestamp is preserved."
# >- "Normalise transport mode using a mapping dictionary instead of .str.lower() alone."
# >- "Add an exception handling block for malformed datetimes."
#
# Keep looping until the cleaning process feels clear, repeatable, and ready for use in the Move AusVille dashboard project.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ---
# ---
#
# # Activity 4: Smart outlier decisions

# %% [markdown]
# ![](https://img.shields.io/badge/Instruction-blue) ![](https://img.shields.io/badge/Step_1-blue)
#
# ## 4.1 Frame the outlier detection problem
#
# In analytics roles, stakeholders rely on your reasoning, not your code.
#
# Good problem framing helps Copilot generate outputs that align with your analytical goals and creates an auditable trail of decisions.
#
# Begin by writing a prompt to Copilot that clearly explains what you’re trying to achieve. Describe:
#
# - the dataset you are working with
# - that you need to calculate trip durations
# - that the dataset contains unrealistic extremes
# - that you want to test both `IQR-based` and `business-rule-based` outlier detection
# - that you need explanations and validation steps
#
# Your prompt should make the context clear so Copilot produces meaningful and defensible logic.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_2-blue)
#
# ## 4.2 Decompose the tasks with Copilot
#
# Industry analytics pipelines succeed when the steps are well defined and testable.
#
# Decomposition ensures each operation has a clear rationale, and avoids guesswork or black box thinking.
#
# Ask Copilot to help break the overall activity into clear, logical sub-steps. These should include:
#
# - Calculating trip durations from `arrival_time` to `departure_time`.
# - Inspecting the distribution of durations.
# - Using the IQR method to identify statistically extreme values.
# - Applying domain-based business rules (e.g., "urban trips < 1 minute or > 3 hours are likely invalid").
# - Comparing the two methods.
# - Proposing validation checks for each method.
# - Recommending what to do with borderline records.
#
# If Copilot gives vague or overly simplistic decomposition, ask it to clarify or expand.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_3-blue)
#
# ## 4.3 Generate initial code with explanatory comments
#
# Modern analysts rarely start from scratch.
#
# Your skill lies in requesting, understanding, and refining generated code (⚠️ not accepting it blindly). This reflects real project workflows.
#
# Ask Copilot to generate code for:
#
# - calculating trip durations
# - applying the IQR outlier detection method
# - applying business-rule filters
# - returning both sets of flagged records
# - printing summaries of what was detected
#
# Then instruct Copilot to:
#
# - improve variable names
# - add inline comments explaining the logic
# - include diagnostic prints (e.g., IQR thresholds, number of outliers detected)
# - propose alternative thresholds or detection methods if needed
#
# Why this matters:

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_4-blue)
#
# ## 4.4 Validate and inspect results
#
# Validation is crucial in industry.
#
# Removing the wrong records can distort downstream analytics. You must justify your choices, not just compute them.
#
#
# With Copilot’s help, examine:
#
# - the ranges of durations flagged by IQR
# - the ranges flagged by business rules
# - whether either method catches unrealistic values
# - how many trips are being removed
# - whether any “normal” trips were incorrectly flagged
#
# Ask Copilot to generate small previews of the suspect records, so you can visually check whether the values make sense.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_5-blue)
#
# ## 4.5 Iterate and adjust thresholds
#
# Data cleaning is rarely finished on the first pass.
#
# Real analysts iterate repeatedly until they can confidently explain each decision to stakeholders.
#
# Based on your validation findings, instruct Copilot to refine your detection logic. For example:
#
# - Adjust IQR multipliers (e.g., 1.5× → 2×).
# - Update business rules (e.g., “max 4 hours for regional buses”).
# - Add exception handling for missing or negative durations.
# - Visualise the duration distribution to support your decision.
# - Compare how changes in thresholds impact the number of flagged trips.
#
# Loop until your rules are defensible, transparent, and consistent with the <span style="color:#B49AD2">Smart City context</span>.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ---
# ---
#
# # Activity 5: Defensible data merging with Copilot

# %% [markdown]
# ![](https://img.shields.io/badge/Instruction-blue) ![](https://img.shields.io/badge/Step_1-blue)
#
# ## 5.1 Frame the merging problem for Copilot
#
# Open Copilot and explain the scenario in your own words.
#
# Describe:
#
# - the two datasets (journey table and route reference table)
# - the intended join keys (e.g., `route_id`, and if needed `service_date` or `operator`. You must justify your choice)
# - the risk that merges can duplicate, drop, or misassign records
# - that you require validation artifacts (row counts before/after, unmatched counts, null fields introduced by the join)
# - that you want both inner and left‑join comparisons to understand trade‑offs
#
# Ask Copilot to confirm assumptions it is making (e.g., that `route_id` is unique in the reference data).
#
# ⚠️ Important: Good framing produces better, safer merging logic and a clear audit trail for your Senior Data Scientist.
#
# LLM prompt seed to adapt (do not copy verbatim):
# >"I’m merging AusVille journey records with route reference metadata. Suggest an approach to choose the correct join keys, highlight risks (duplication, dropped records, mismatched modes), and generate code with comments to compare left vs inner joins, compute match rates, and produce validation tables. Include diagnostics I can show to a Senior Data Scientist."

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_2-blue)
#
# ## 5.2 Decompose the work into sub‑tasks
#
# Ask Copilot to draft a step‑by‑step plan. Your decomposition should include:
#
# - <span style="color:#B49AD2">Key analysis</span>: Check uniqueness and cleanliness of join keys in both tables; propose fixes if keys are messy (trimming, casing, padding, and type alignment).
# - <span style="color:#B49AD2">Join strategy</span>: Compare left, inner, (and optionally right) joins; explain when each is appropriate in transport operations.
# - <span style="color:#B49AD2">Validation metrics</span>:
#
#     - Row counts before and after each join.
#     - Match rate = matched journeys / total journeys.
#     - Counts of unmatched `route_ids` and duplicate matches.
#     - New NULLs in reference fields after the join.
#
#
# - <span style="color:#B49AD2">Risk checks</span>:
#
#     - Journeys with `transport_mode` that disagree with the reference `route_type`.
#     - Implausible combinations (e.g., operator = `tram_co` but `route_type` = bus).
#     - Surprising expansions in row count (accidental one‑to‑many join).
#
#
# - <span style="color:#B49AD2">Remediation options</span>: Propose rules to resolve common issues (e.g., standardise route_id formats; choose the most recent record when reference has multiple rows per route and date).
#
# - <span style="color:#B49AD2">Reporting artifacts</span>: Produce small summary tables and a short LLM‑generated explanation suitable for your project notes.
#
# Push Copilot if the plan is vague. Ask for explicit checks and clear metrics.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_3-blue)
#
# ## 5.3 Generate initial merge and validation code
#
# Instruct Copilot to write code (e.g., in Python/pandas) that:
#
# - cleans and aligns your join keys (type casting, trimming, case normalisation)
# - runs two joins (left and inner) into separate DataFrames
# - computes row deltas, match rates, and unmatched lists
# - produces top‑N samples of suspicious cases (e.g., multiple reference matches; missing `route_id` in reference)
# - prints a compact validation report (counts before/after, % matched, number of NULLs introduced, number of duplicate `journey_ids` after merge)
# - includes inline comments explaining the rationale for each operation
#
# If the code is hard to read, tell Copilot to refactor it for:
#
# - clearer variable names
# - grouped logic
# - comments that a future analyst would understand

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_4-blue)
#
# ## 5.4 Validate the join and inspect inconsistencies
#
# With Copilot’s help, interrogate the results:
#
# - Compare left vs inner join outcomes.
#     - Which better fits a production pipeline for the dashboard?
#     - Why?
# - Review the unmatched journey rows: are route_ids missing, malformed, or from an operator not present in reference?
# - Check for row inflation (journey count increased) indicating a one‑to‑many merge. Identify the column(s) causing duplication (e.g., reference table has multiple records per route due to effective dates).
# - Scan for semantic inconsistencies introduced by the merge:
#     - `transport_mode` vs `route_type disagreement`
#     - operator conflicts
#     - implausible `planned_stops` compared to journey `recorded_stops` (e.g., planned 10 stops but recorded 57).
#
#
# Ask Copilot to generate small preview tables of each issue type and a short, human‑readable explanation of likely causes.
#
# Document what you found and what you would fix next.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_5-blue)
#
# ## 5.5 Iterate and harden your approach
#
# Based on the findings, refine your merge logic with Copilot:
#
# - Standardise `route_id` patterns (e.g., remove prefixes, pad zeros) and re‑join; compare new match rate.
# - If reference data is one‑to‑many, design a selection rule (e.g., most recent `effective_date` ≤ journey date).
# - Add assertions (e.g., “post‑merge rows must equal pre‑merge journeys” for inner joins, or “match rate must exceed 95%” for left joins).
# - Produce a final validation summary and a brief justification of your chosen method for the Senior Data Scientist.
#
# Repeat until your join is defensible, reproducible, and auditable.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ---
# ---
#
# # Activity 6: Final data validation

# %% [markdown]
# ![](https://img.shields.io/badge/Instruction-blue) ![](https://img.shields.io/badge/Step_1-blue)
#
# ## 6.1 Frame the final validation task for Copilot
#
# Begin by clearly describing what you want Copilot to help you validate.
#
# Include:
#
# - that this is the final quality check for the Move AusVille journey dataset
# - which fields need re‑inspection (e.g., durations, `transport_mode`, passenger counts, route details)
# - that you want summary statistics, categorical audits, and exception reports
# - that you want Copilot to propose additional checks you might have missed
#
# ⚠️ Important: In your prompt, emphasise that this is the final confirmation before dataset export.
#
# LLM output should therefore be rigorous and cautious.
#
# Example starter (do NOT copy directly):
#
# >"I am performing final validation of the cleaned Move AusVille journey dataset. Suggest a structured plan to re‑run summary statistics, verify duration logic, audit categorical values, and check for any remaining anomalies before export. Include tests I may have overlooked."

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_2-blue)
#
# ## 6.2 Decompose validation tasks with Copilot
#
# Ask Copilot to help you break the final validation into clear sub‑steps, such as:
#
# - Recalculate summary statistics (min, max, mean, quartiles) for key fields
# - Confirm duration fields contain no zero, negative, or overly large values
# - List unique categorical values (`transport_mode`, `operator`, `route_type`)
# - Check for unexpected new NULLs introduced during cleaning
# - Flag suspicious edge cases (e.g., extremely high passenger counts)
# - Identify any logical inconsistencies (e.g., bus routes with ferry modes)
#
# Review Copilot’s plan and ask it to refine or expand sections that seem vague.
#
# This decomposition ensures you don’t overlook subtle issues.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_3-blue)
#
# ## 6.3 Run validation code with Copilot’s help
#
# Ask Copilot to generate validation snippets (e.g., using Python/pandas) that:
#
# - re‑run summary statistics for duration, `passenger_count`, and stop counts
# - display the top/bottom 5 rows for key numeric fields
# - list all unique categorical values in alphabetical order
# - highlight any records outside expected ranges
# - produce a short validation report summarising possible risks
#
# Request Copilot to:
#
# - add explanatory comments
# - adjust variable names for clarity
# - insert assertions, such as:
#     - `assert duration.min() > 0`
#     - `assert not df.transport_mode.isnull().any()`
#
#
# If something looks odd, ask Copilot for deeper inspection.
# >For example, printing the rows that triggered a failure.
#
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_4-blue)
#
# ## 6.4 Iterate and resolve issues
#
# If your validation identifies any problems:
# - strange values
# - inconsistent labels
# - unexpected NULLs
#
# Work with Copilot to:
#
# - diagnose the cause
# - recommend a fix
# - apply that fix
# - re‑validate to confirm the issue is resolved
#
# This final iteration demonstrates professional practice. Never export until every validation step passes cleanly.

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>

# %% [markdown]
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ---
#
# ![](https://img.shields.io/badge/Step_5-blue)
#
# ## 6.5 Export the final dataset
#
# Once all tests pass and Copilot confirms that no further anomalies remain.
#
# Ask Copilot for code to export your cleaned dataset properly.
#
# Ensure the filename reflects the Move AusVille standards (<span style="color:#B49AD2">journey_records_clean.csv</span>).
#
# Validate the export by quickly checking:
#
# - file size
# - expected number of rows
# - presence of key columns
# - no truncated data
#
# You may also ask Copilot to generate a short paragraph summarising your validation steps for your <span style="color:#B49AD2">Cleaning Log</span>.
#
# ### 💻 <span style="color:#ED6B5E">Write your group’s coding below:</span>

# %%
# Input your code here

# %% [markdown]
# ### ✏️ <span style="color:#ED6B5E">Write your group’s responses here:</span>
